# %%
import tensorflow as tf
import numpy as np
from google.colab import files
# uploaded = files.upload()

# %%
# 데이터 불러오기

wave_train = np.loadtxt('abc_wave_counting2.csv', delimiter=',', skiprows=1, dtype=np.float32)
                                                                    # data의 type을 처음부터 설정해서 가져옴.

# X
x_train = wave_train[:, :-1] # 마지막 컬럼을 제외
            #[행, 열]
    # print(data_train)
    # print(x_train)
        # 두 아이를 비교해서 어떻게 가져왔는지 확인.

# Y
y_train = wave_train[:, [-1]] # 마지막 컬럼만 2차원으로 추출
          # [;, -1:] 이렇게도 가능.
# 행렬 확인
print(x_train.shape, y_train.shape)

# 슬라이싱 확인
print(x_train)
# Out:
# (11, 8) (11, 1)
# [[0.000000e+00 0.000000e+00 0.000000e+00 9.750000e+02 4.990000e+02
#   2.620849e+04 2.574466e+04 2.602967e+04]
#  [0.000000e+00 0.000000e+00 1.000000e+00 1.601000e+03 4.020000e+02
#   2.560345e+04 2.590660e+04 2.577557e+04]
#  [0.000000e+00 0.000000e+00 0.000000e+00 3.260000e+02 5.850000e+02
#   2.593261e+04 2.572061e+04 2.586489e+04]
#  [0.000000e+00 0.000000e+00 1.000000e+00 1.358000e+03 2.660000e+02
#   2.626948e+04 2.650370e+04 2.642413e+04]
#  [0.000000e+00 0.000000e+00 1.000000e+00 3.820000e+02 2.110000e+02
#   2.644099e+04 2.668699e+04 2.655903e+04]
#  [0.000000e+00 0.000000e+00 1.000000e+00 1.358000e+03 2.660000e+02
#   2.626948e+04 2.657689e+04 2.644099e+04]
#  [0.000000e+00 0.000000e+00 1.000000e+00 9.380000e+02 6.750000e+02
#   2.641545e+04 2.657297e+04 2.651546e+04]
#  [0.000000e+00 0.000000e+00 0.000000e+00 2.130000e+02 3.210000e+02
#   2.665069e+04 2.655292e+04 2.660311e+04]
#  [0.000000e+00 0.000000e+00 0.000000e+00 2.130000e+02 3.210000e+02
#   2.665069e+04 2.643037e+04 2.659727e+04]
#  [1.000000e+00 1.000000e+00 1.000000e+00 7.940000e+02 4.140000e+02
#   2.612793e+04 2.637369e+04 2.623184e+04]
#  [0.000000e+00 0.000000e+00 1.000000e+00 4.780000e+02 2.960000e+02
#   2.621110e+04 2.643600e+04 2.629134e+04]]

# %%
# 변수 초기화 : weight, bias

tf.random.set_seed(5) # seed 고정

            # 행렬의 내적곱
                  #    X     *    W   =    Y
                  # (m, n)   *  (n, L) = (m, L)
                  # (11, 8) *  (_, _) = (11, 1)
W = tf.Variable(tf.random.normal([8,1]), name='weight')
                          # 정규분포로 만듦

b = tf.Variable(tf.random.normal([1]), name='bias')


print('Weight :',W.numpy().T)
print('bais :',b.numpy())
# Out:
# Weight : [[-0.18030666 -0.95028627 -0.03964049 -0.7425406   1.3231523  -0.61854804
#    0.8540664  -0.08899953]]
# bais : [0.22652864]

# %%
# 예측 함수(hypothesis) : H(x) = W*X + b

def hypothesis(X) :
    return tf.matmul(X,W) + b

# %%
# 비용 함수(cost function) : (H(x) - y)^2 의 평균
# tf.square() : 제곱

def cost_func():
    cost = tf.math.log(tf.reduce_mean(tf.square(hypothesis(x_train) - y_train)))
    return cost

# %%
# 경사 하강법(Gradient descent)

# optimizer = tf.compat.v1.train.GradientDescentOptimizer(learning_rate=0.01) # 그레디언트
# optimizer = tf.compat.v1.train.AdadeltaOptimizer(learning_rate=0.01) # 아담
optimizer = tf.keras.optimizers.Adam(learning_rate = 0.01) # 케라스
                                                   # 학습율

# %%
# 학습 시작
print('*'*5,'Start Learnimg!!')
for step in range(10001):
    optimizer.minimize(cost_func,var_list=[W,b])
                    # 비용 함수 ,     Weight, bais
    if step % 500 == 0:
        print(f'''{step:0>4} cost :[ {cost_func().numpy()} ] b : [ {b.numpy()} ]
        W : [ {W.numpy().T} ]''')


print('*'*5,'Learnimg Finished!!')
# Out:
# ***** Start Learnimg!!
# 0000 cost :[ 19.972518920898438 ] b : [ [0.23618458] ]
#         W : [ [[-0.17312554 -0.94310516 -0.0301651  -0.7325411   1.3331513  -0.6085481
#    0.8640663  -0.07899961]] ]
# 0500 cost :[ 7.846445083618164 ] b : [ [0.49140427] ]
#         W : [ [[ 2.972389    2.2024086   4.4048634   0.10617444 -0.04659787 -0.37095368
#    1.1784995   0.18921104]] ]
# 1000 cost :[ 7.688034534454346 ] b : [ [0.5045565] ]
#         W : [ [[ 5.382219    4.6122403   7.5831585   0.09829002 -0.02627943 -0.39326298
#    1.2049494   0.1848734 ]] ]
# 1500 cost :[ 7.57975435256958 ] b : [ [0.5208777] ]
#         W : [ [[ 6.1884794e+00  5.4185009e+00  1.0200983e+01  9.2032067e-02
#   -9.9229161e-03 -4.1070282e-01  1.2258350e+00  1.8126637e-01]] ]
# 2000 cost :[ 7.497483730316162 ] b : [ [0.53976953] ]
#         W : [ [[ 5.9356036e+00  5.1656251e+00  1.2397217e+01  8.7020166e-02
#    3.3700969e-03 -4.2438820e-01  1.2424608e+00  1.7820668e-01]] ]
# 2500 cost :[ 7.434385299682617 ] b : [ [0.5607561] ]
#         W : [ [[ 5.0940580e+00  4.3240795e+00  1.4251579e+01  8.2979232e-02
#    1.4224412e-02 -4.3516430e-01  1.2557991e+00  1.7555428e-01]] ]
# 3000 cost :[ 7.3866353034973145 ] b : [ [0.5834579] ]
#         W : [ [[ 3.993531    3.2235503  15.824669    0.07970264  0.02310753 -0.44366235
#    1.2665712   0.17320912]] ]
# 3500 cost :[ 7.350245952606201 ] b : [ [0.60756606] ]
#         W : [ [[ 2.8279603   2.0579796  17.16538     0.07703552  0.0303886  -0.45035756
#    1.2753192   0.17109983]] ]
# 4000 cost :[ 7.323866844177246 ] b : [ [0.63282853] ]
#         W : [ [[ 1.7008417   0.9308591  18.313793    0.07485563  0.03636066 -0.45561478
#    1.282456    0.16917294]] ]
# 4500 cost :[ 7.303840637207031 ] b : [ [0.6590422] ]
#         W : [ [[ 0.6629686  -0.1070143  19.303057    0.07307093  0.04126478 -0.45971525
#    1.2883003   0.1673904 ]] ]
# 5000 cost :[ 7.289429187774658 ] b : [ [0.68603814] ]
#         W : [ [[-0.26445797 -1.0344412  20.16051     0.07160658  0.0452903  -0.4628813
#    1.2931012   0.16572255]] ]
# 5500 cost :[ 7.278650283813477 ] b : [ [0.7136785] ]
#         W : [ [[-1.0767803  -1.8467624  20.908749    0.07040263  0.04859772 -0.46528795
#    1.2970552   0.16414736]] ]
# 6000 cost :[ 7.271527290344238 ] b : [ [0.7418502] ]
#         W : [ [[-1.7784218  -2.5484028  21.566423    0.06941112  0.05131229 -0.467077
#    1.3003207   0.16264613]] ]
# 6500 cost :[ 7.265524387359619 ] b : [ [0.7704622] ]
#         W : [ [[-2.3784642  -3.1484468  22.148973    0.0685962   0.05353906 -0.4683595
#    1.3030223   0.16120695]] ]
# 7000 cost :[ 7.261711597442627 ] b : [ [0.7994356] ]
#         W : [ [[-2.888003   -3.6579857  22.669123    0.06792387  0.0553652  -0.46922964
#    1.3052644   0.15981662]] ]
# 7500 cost :[ 7.259000778198242 ] b : [ [0.8287082] ]
#         W : [ [[-3.3186238  -4.088608   23.137402    0.06737074  0.05685699 -0.46975994
#    1.3071274   0.15846789]] ]
# 8000 cost :[ 7.256570339202881 ] b : [ [0.858228] ]
#         W : [ [[-3.6813934  -4.4513807  23.562498    0.06691432  0.05807585 -0.47001165
#    1.30868     0.15715344]] ]
# 8500 cost :[ 7.2545928955078125 ] b : [ [0.88795215] ]
#         W : [ [[-3.9865298  -4.756524   23.951616    0.06653824  0.05907069 -0.47003448
#    1.3099774   0.15586708]] ]
# 9000 cost :[ 7.253032207489014 ] b : [ [0.91784483] ]
#         W : [ [[-4.243082   -5.013077   24.310701    0.06622911  0.0598768  -0.4698697
#    1.3110651   0.15460432]] ]
# 9500 cost :[ 7.25206184387207 ] b : [ [0.94787604] ]
#         W : [ [[-4.458845   -5.22884    24.644718    0.06597485  0.06052997 -0.46955028
#    1.3119788   0.15336166]] ]
# 10000 cost :[ 7.251252174377441 ] b : [ [0.97802216] ]
#         W : [ [[-4.6406384  -5.410633   24.957714    0.0657654   0.06105566 -0.46910375
#    1.3127494   0.152136  ]] ]
# ***** Learnimg Finished!!

# %%
# 회귀 계수 출력
print('Weight =', W.numpy())
print('Bias =', b.numpy())
print()
# Out:
# Weight = [[-4.6406384 ]
#  [-5.410633  ]
#  [24.957714  ]
#  [ 0.0657654 ]
#  [ 0.06105566]
#  [-0.46910375]
#  [ 1.3127494 ]
#  [ 0.152136  ]]
# Bias = [0.97802216]

# %%
# 정확도 측정 : RMSE(Root Mean Squared Error)

def get_rmse(y_test,preds): # preds는 predicts의 약자
    squared_error = 0 # 오차를 쌓아야 하니까 변수 초기화.
    for k,_ in enumerate(y_test): # 사용하지 않을 변수는 _로 한다. k는 index를 가져온 것.
        squared_error += (preds[k] - y_test[k])**2
    mse = squared_error/len(y_test)
    rmse = np.sqrt(mse)
    return rmse[0]

# 학습한 데이터를 그대로 검증 데이터로 사용한 경우
x_test = x_train
y_test = y_train

preds = hypothesis(x_test).numpy()
print('RMSE:',get_rmse(y_test,preds))
# Out:
# RMSE: 37.548218

# %%
# 예측
print('***** Predict')
x_data = [[0,0,1,2275,688,29967,30330.5,30169.5]]
x_test = np.array(x_data,dtype=np.float32)

print(hypothesis(x_test).numpy())

predict = float(hypothesis(x_test).numpy())

print(predict - 30583.5)
# Out:
# ***** Predict
# [[30566.139]]
# -17.361328125
